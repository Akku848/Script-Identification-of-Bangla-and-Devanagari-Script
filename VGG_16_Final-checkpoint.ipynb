# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
img_width, img_height = 32,32
train_data_dir = 'C:/Users/aksha/Downloads/My_Dataset_Dev_Train/My_Dataset_Dev_Train/train'
validation_data_dir = 'C:/Users/aksha/Downloads/My_Dataset_Dev_Train/My_Dataset_Dev_Train/val'
nb_train_samples = 100
nb_validation_samples = 500
epochs = 120
batch_size = 4
num_classes = 17

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))
model = tf.keras.Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 502 images belonging to 17 classes.

# %%
validation_generator = test_datagen.flow_from_directory(validation_data_dir,
                                                        target_size=(img_width, img_height),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
# Out:
# Found 145 images belonging to 17 classes.

# %%
model.fit(train_generator,
          steps_per_epoch=nb_train_samples // batch_size,
          epochs=epochs,
          validation_data=validation_generator,
          validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/120
# 25/25 [==============================] - ETA: 0s - loss: 2.9795 - accuracy: 0.1100WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 125 batches). You may need to use the repeat() function when building your dataset.
# 25/25 [==============================] - 2s 63ms/step - loss: 2.9795 - accuracy: 0.1100 - val_loss: 2.7489 - val_accuracy: 0.1241
# Epoch 2/120
# 25/25 [==============================] - 1s 23ms/step - loss: 2.6546 - accuracy: 0.1700
# Epoch 3/120
# 25/25 [==============================] - 1s 23ms/step - loss: 2.7216 - accuracy: 0.1531
# Epoch 4/120
# 25/25 [==============================] - 1s 23ms/step - loss: 2.5708 - accuracy: 0.2200
# Epoch 5/120
# 25/25 [==============================] - 1s 23ms/step - loss: 2.4312 - accuracy: 0.2755
# Epoch 6/120
# 25/25 [==============================] - 1s 23ms/step - loss: 2.2970 - accuracy: 0.2551
# Epoch 7/120
# 25/25 [==============================] - 1s 24ms/step - loss: 2.0961 - accuracy: 0.3800
# Epoch 8/120
# 25/25 [==============================] - 1s 24ms/step - loss: 2.1868 - accuracy: 0.2900
# Epoch 9/120
# 25/25 [==============================] - 1s 25ms/step - loss: 2.1287 - accuracy: 0.3200
# Epoch 10/120
# 25/25 [==============================] - 1s 24ms/step - loss: 2.0190 - accuracy: 0.4000
# Epoch 11/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.9457 - accuracy: 0.3600
# Epoch 12/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.7910 - accuracy: 0.5100
# Epoch 13/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.9379 - accuracy: 0.3700
# Epoch 14/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.7841 - accuracy: 0.4400
# Epoch 15/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.7026 - accuracy: 0.5200
# Epoch 16/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.8086 - accuracy: 0.4694
# Epoch 17/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.6089 - accuracy: 0.5300
# Epoch 18/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.5773 - accuracy: 0.4800
# Epoch 19/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.4885 - accuracy: 0.5700
# Epoch 20/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.4753 - accuracy: 0.6000
# Epoch 21/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.6376 - accuracy: 0.4900
# Epoch 22/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.4562 - accuracy: 0.5500
# Epoch 23/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.4056 - accuracy: 0.5714
# Epoch 24/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.3183 - accuracy: 0.5800
# Epoch 25/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.3141 - accuracy: 0.6100
# Epoch 26/120
# 25/25 [==============================] - 1s 25ms/step - loss: 1.2606 - accuracy: 0.6400
# Epoch 27/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.4817 - accuracy: 0.5000
# Epoch 28/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.2845 - accuracy: 0.5600
# Epoch 29/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.3489 - accuracy: 0.5612
# Epoch 30/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.1283 - accuracy: 0.6600
# Epoch 31/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9915 - accuracy: 0.6531
# Epoch 32/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.2592 - accuracy: 0.5714
# Epoch 33/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.3073 - accuracy: 0.5900
# Epoch 34/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.2576 - accuracy: 0.6000
# Epoch 35/120
# 25/25 [==============================] - 1s 25ms/step - loss: 1.1962 - accuracy: 0.6400
# Epoch 36/120
# 25/25 [==============================] - 1s 25ms/step - loss: 1.1653 - accuracy: 0.7300
# Epoch 37/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.9602 - accuracy: 0.7300
# Epoch 38/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.2334 - accuracy: 0.6531
# Epoch 39/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.0919 - accuracy: 0.6800
# Epoch 40/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.2059 - accuracy: 0.6200
# Epoch 41/120
# 25/25 [==============================] - 1s 25ms/step - loss: 1.1255 - accuracy: 0.6300
# Epoch 42/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.0706 - accuracy: 0.6800
# Epoch 43/120
# 25/25 [==============================] - 1s 25ms/step - loss: 1.0374 - accuracy: 0.6500
# Epoch 44/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8512 - accuracy: 0.7500
# Epoch 45/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9642 - accuracy: 0.7200
# Epoch 46/120
# 25/25 [==============================] - 1s 23ms/step - loss: 1.0651 - accuracy: 0.6300
# Epoch 47/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9808 - accuracy: 0.6939
# Epoch 48/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9823 - accuracy: 0.7100
# Epoch 49/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8710 - accuracy: 0.7143
# Epoch 50/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8125 - accuracy: 0.7551
# Epoch 51/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8383 - accuracy: 0.7100
# Epoch 52/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9792 - accuracy: 0.7200
# Epoch 53/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.7712 - accuracy: 0.7449
# Epoch 54/120
# 25/25 [==============================] - 1s 24ms/step - loss: 1.0170 - accuracy: 0.7000
# Epoch 55/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9558 - accuracy: 0.7400
# Epoch 56/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8991 - accuracy: 0.7200
# Epoch 57/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9800 - accuracy: 0.6800
# Epoch 58/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8522 - accuracy: 0.7900
# Epoch 59/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.7638 - accuracy: 0.8000
# Epoch 60/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.8201 - accuracy: 0.7300
# Epoch 61/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.6565 - accuracy: 0.8300
# Epoch 62/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.9020 - accuracy: 0.7300
# Epoch 63/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.7451 - accuracy: 0.7900
# Epoch 64/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8274 - accuracy: 0.7600
# Epoch 65/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8085 - accuracy: 0.7500
# Epoch 66/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.8045 - accuracy: 0.7000
# Epoch 67/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8737 - accuracy: 0.7300
# Epoch 68/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.9016 - accuracy: 0.6600
# Epoch 69/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6925 - accuracy: 0.7700
# Epoch 70/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8143 - accuracy: 0.7300
# Epoch 71/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.8482 - accuracy: 0.7000
# Epoch 72/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.7552 - accuracy: 0.7200
# Epoch 73/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6396 - accuracy: 0.8000
# Epoch 74/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6114 - accuracy: 0.8100
# Epoch 75/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6318 - accuracy: 0.8200
# Epoch 76/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.7896 - accuracy: 0.7800
# Epoch 77/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8011 - accuracy: 0.7100
# Epoch 78/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.7644 - accuracy: 0.7500
# Epoch 79/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6734 - accuracy: 0.7900
# Epoch 80/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6570 - accuracy: 0.8000
# Epoch 81/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5509 - accuracy: 0.8300
# Epoch 82/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5758 - accuracy: 0.8100
# Epoch 83/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6641 - accuracy: 0.7300
# Epoch 84/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6868 - accuracy: 0.7700
# Epoch 85/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5537 - accuracy: 0.7959
# Epoch 86/120
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5102 - accuracy: 0.8500
# Epoch 87/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.8230 - accuracy: 0.7200
# Epoch 88/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.7582 - accuracy: 0.7300
# Epoch 89/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6636 - accuracy: 0.7857
# Epoch 90/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5393 - accuracy: 0.8400
# Epoch 91/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6250 - accuracy: 0.7900
# Epoch 92/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6028 - accuracy: 0.8163
# Epoch 93/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6658 - accuracy: 0.7900
# Epoch 94/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6561 - accuracy: 0.7900
# Epoch 95/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5957 - accuracy: 0.8200
# Epoch 96/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6689 - accuracy: 0.7700
# Epoch 97/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6137 - accuracy: 0.8000
# Epoch 98/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5859 - accuracy: 0.8200
# Epoch 99/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.7835 - accuracy: 0.7400
# Epoch 100/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.7361 - accuracy: 0.7449
# Epoch 101/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6711 - accuracy: 0.7449
# Epoch 102/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6271 - accuracy: 0.8100
# Epoch 103/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.7563 - accuracy: 0.6900
# Epoch 104/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5520 - accuracy: 0.8300
# Epoch 105/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6504 - accuracy: 0.7755
# Epoch 106/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.4933 - accuracy: 0.8600
# Epoch 107/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5989 - accuracy: 0.8300
# Epoch 108/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5286 - accuracy: 0.8300
# Epoch 109/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5150 - accuracy: 0.8200
# Epoch 110/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5403 - accuracy: 0.8300
# Epoch 111/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.6472 - accuracy: 0.7500
# Epoch 112/120
# 25/25 [==============================] - 1s 27ms/step - loss: 0.7077 - accuracy: 0.7700
# Epoch 113/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.4963 - accuracy: 0.8061
# Epoch 114/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5642 - accuracy: 0.7959
# Epoch 115/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5358 - accuracy: 0.8300
# Epoch 116/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.4993 - accuracy: 0.8400
# Epoch 117/120
# 25/25 [==============================] - 1s 25ms/step - loss: 0.4859 - accuracy: 0.8600
# Epoch 118/120
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6568 - accuracy: 0.7800
# Epoch 119/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.4868 - accuracy: 0.8300
# Epoch 120/120
# 25/25 [==============================] - 1s 23ms/step - loss: 0.4780 - accuracy: 0.8400

# %%
# Save the trained model
model.save('bangla_devanagari_vgg16.h5')

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# Define the input shape of the model
input_shape = (32, 32, 3)

# Load the trained model
model = load_model('C:/Users/aksha/Downloads/My_Dataset_Dev_Train/My_Dataset_Dev_Train/bangla_devanagari_vgg16.h5')

# Define the class labels
class_labels = ["त", "थ", "द", "ध", "न", "प", "फ", "ब", "भ", "म", "य", "र", "ल", "व", "श", "ष", "स"]

# Create a GUI window
window = tk.Tk()
window.title("VGG16 Image Classifier")

# Define a function to load an image file
def load_image():
    # Open a file dialog to select an image file
    file_path = filedialog.askopenfilename()
    # Load the image file using PIL
    image = Image.open(file_path)
    # Resize the image to the input shape of the model
    image = image.convert("RGB")

# Resize the image to the desired input shape
    image = image.resize((32, 32))

# Convert the image to a numpy array
    image_array = np.array(image)

# Normalize the image data
    image_array = image_array / 255.0

# Add a batch dimension to the image array
    image_array = np.expand_dims(image_array, axis=0)

# Use the image array as input to your model
    model.predict(image_array)
    # Return the image array
    return image_array

# Define a function to classify an image
# Define a function to classify an image
def classify_image():
    # Load the image
    image = load_image()
    # Get the model's prediction for the image
    prediction = model.predict(image)
    # Get the class label with the highest prediction value
    class_index = np.argmax(prediction)
    class_label = class_labels[class_index]
    # Update the GUI label with the class label
    label.config(text=class_label)


# Create a button to load an image
load_button = tk.Button(window, text="Load Image", command=classify_image)
load_button.pack()

# Create a label to display the class label
label = tk.Label(window, text="")
label.pack()

# Start the GUI event loop
window.mainloop()
